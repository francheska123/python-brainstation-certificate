# %% [markdown]
# <div id="container" style="position:relative;">
# <div style="float:left"><h1> Python Basics </h1></div>
# <div style="position:relative; float:right"><img style="height:65px" src ="data:image/png;base64,..." />
# </div>
# </div>

# %% [markdown]
# # Learning Outcomes
#
# - How to use Jupyter Notebooks.
# - Understand the basic data types.
# -  Understand how to define variables to store values for later use.
# - Perform mathematical calculations using the appropriate mathematical operators.
# - Navigate through control flows in Python.

# %% [markdown]
# Table of Contents
# =================
#
# 1. [Lesson Introduction](#Lesson-Introduction)
# 2. [The Rise of Python](#The-Rise-of-Python)
# 3. [Jupyter Notebook Essentials](#Jupyter-Notebook-Essentials)
# 4. [Basic Data Types in Python](#Basic-Data-Types-in-Python)
# 5. [Python Syntax](#Python-Syntax)
#    - [Creating a Variable in Python](#Creating-a-Variable-in-Python)
# 6. [Working with Numbers](#Working-with-Numbers)
# 7. [In-Class Code-Along: Expressions (20 Mins)](#In-Class-Code-Along:-Expressions-(20-Mins))
# 8. [Working with Strings](#Working-with-Strings)
# 9. [Working with Booleans](#Working-with-Booleans)
# 10. [Control Flow](#Control-Flow)
#    - [Comparison Operators](#Comparison-Operators)
#    - [Logical Operators](#Logical-Operators)
#    - [If and Else Statements](#If-and-Else-Statements)
# 11. [In-Class Code-Along: Control Flows (20 Mins)](#In-Class-Code-Along:-Control-Flows-(20-Mins))
# 12. [Key Takeaways](#Key-Takeaways)
# 13. [Next Up](#Next-Up)

# %% [markdown]
# # Lesson Introduction
#
# Python has become a cornerstone in different business sectors, including programming, web development, machine learning, and data science. Its rise to the top of the programming world, even surpassing Java, can be attributed to its straightforward syntax and robust support for a wide range of packages and libraries. This adaptability makes Python the go-to choice for tasks like data science projects or constructing machine learning models. In this lesson, we'll start getting familiar with Python by delving into how to create and utilize variables, various data structures and types in Python. Additionally, we'll learn how to create conditional flows, which are crucial for creating logical processing pipelines and automating functions.

# %% [markdown]
# ## The Rise of Python
#
# Python utilization has risen rapidly in the last decade and is currently one of the [most used coding languages](https://www.statista.com/statistics/793628/worldwide-developer-survey-most-used-languages/) in some of the top companies globally due to the folowing reasons:
# - Ease of use due to human readable code;
# - Ability to create complex applications to automate tasks;
# - Ability to be used for data manipulation and modeling;
# - Availability of open source reusable code with a very supportive community.

# %% [markdown]
# ## Jupyter Notebook Essentials
#
# Welcome to your first Jupyter Notebook (from this course at least). Jupyter Notebook (formerly known as IPython Notebook) is an interactive web application for creating and sharing coding documents. The project was first named IPython and later renamed Jupyter in 2014. It is a fully open-source product, and users can use every functionality available for free.
# Since 2014 notebook has become one of the most popular platforms for Data Science projects. They can be executed both locally on your machine and in cloud-based environments, providing access to powerful computational resources. Most major machine learning and cloud service providers, such as Google Colab, Amazon SageMaker, Databricks, and Snowflake, have built their data science tooling around notebook interfaces. These platforms support the creation of multi-notebook workflows, which allows for modular coding and enhance productivity and collaboration. It is also preferred for learning as it allows for a simple markdown to coding cell transition which works well for taking notes or making reports. Some of the shortcuts for ease of use are given below.
#
#
# **Basics for Running Cells: Coding & Markdown**
# - Press `Esc` for Edit Mode
# - Press `Enter` for Command Mode
#
#
# - `Y` for Code
# - `M` for Markdown
# - Notice menu on the top right of each cell for copying and moving cells.
#
#
# - `Shift + Return` to run a cell in Code or Markdown, select cell below
# - `Command + Return` to run a cell in Code or Markdown

# %% [markdown]
# **Basic Shortcuts in Edit Mode (ESC)**
# - `A` for Add Cell **A**bove
# - `B` for Add Cell **B**elow
# - `C` for **C**opy
# - `V` for Paste
# - `D+D` for **D**elete
# - `X` for Cut
#
# - For more shortcuts you can go to `Help -> Keyboard Shortcuts`
#
#
# Windows vs Macs: Newer Macs may only need to press the letter.  Windows or old Mac users may need to press `CTRL + ` or `CMND + ` respectively.

# %% [markdown]
# ## Basic Data Types in Python
#
# ### Why Types Matter
# Types matter as we need our data to be predictable and represented appropriately. Some programming languages are strict about types but in Python it is known to have "Duck Typing". The idea of a duck-typed programming language is that "if it walks like a duck and quacks like a duck, then it must be a duck".
#
# The benefit of a Duck-Typed language is that its main focus is more about convenience than type safety. This allows for more flexibility while programming and for that reason, Python is an ideal language for beginners.
#
#
#
# ### Strings
# Strings represent values that are characters, words or any other type of text. An example of a use case for a string is person's first name or the title of your favorite book.
#
#
# ### Numbers
# Python has several ways to represent numbers, including:
# - Integer: Used for whole numbers
# - Float: Used for fractional or irrational numbers
#
#
# Conversion is automatically done between them and for division floats are the preffered format.
#
# ### Booleans
# Represent a dichotomy as either:
# - True
# - False
#
# They can be used to check and compare numbers, strings or conditions.
#
# ---

# %% [markdown]
# ## Python Syntax
# Syntax can be understood as the types of characters used and how they can be arranged to form a specific ruleset. In Python, we use symbols and indentation to form a set of rules to write python code. For our Python code to run, we must use a Python interpreter to read and understand our syntax. An interpreter is a computer program used to directly read and execute source code.
#
# ## Variables
# In mathematics we can write the following:<br>
#     &nbsp;&nbsp; x = 1 <br>
#     &nbsp;&nbsp; y = 2 <br>
#     &nbsp;&nbsp; z = x + y <br><br>
# These simple math variables represent the syntax for the addition of two numbers. In Python, the syntax for defining a variable and adding numbers is identical.

# %%
# Syntax for addition
x = 1
y = 2
z = x + y
print(z)
# Out:
# 3

# %% [markdown]
# ### Creating a Variable in Python
# Variables allow us to store information that can later be used in an expression. To define a variable in Python, we must first state the name we want our variable to be. To assign a value to that name, we must use the "Assignment Operator" which is denoted by the equal (`=`) symbol. Finally, on the right-hand side of the equal sign (`=`), we give it the value we want our variable to hold.
#
# >Note: You may use any word to name your variable however there are specific keywords that are reserved in Python that cannot be used as variable names. Please refer [here](https://docs.python.org/3/library/keyword.html) to learn more about how to determine if a string is a keyword.
#
# ## Expressions vs. Statements
# ### Expressions
# An expression is simply a value except it can contain operations such as addition or subtraction. An example of an expression is the right-hand side of defining a variable.
# ### Statements
# A statement is an instruction that the python interpreter can understand and execute.

# %% [markdown]
# <img src="data:image/png;base64,..." style='float:left'/>

# %% [markdown]
# ## Working with Numbers
# ### Mathematical Operators
# <img src="data:image/png;base64,..." style='float:left;' />

# %% [markdown]
# Python evaluates every mathematical expression by following the BEDMAS ruleset. Try manipulating the expression below by removing the brackets to see the difference in evaluation. To see this new evaluation, select the `Run` button at the top of the page.

# %%
lucky = 2 * (45 - 2**2) - (12 / 2) + 1

#Do not remove brackets from the print function
print(lucky)
# Out:
# 77.0

# %% [markdown]
# Python has several types to represent `number`s including Integer and Float.
#     - Integer is used to represent whole numbers
#     - Float is used to represent fractional or irrational numbers

# %%
integer_number = 10 / 2
print(integer_number)

float_number = 10.0 / 2.0
print(float_number)

missing_remainder = 10 / 3
print(missing_remainder)

multi_type_numbers = 10 / 6.0
print(multi_type_numbers)
# Out:
# 5.0
# 5.0
# 3.3333333333333335
# 1.6666666666666667

# %% [markdown]
# Python will automatically convert each expression to its appropriate number type. If we wanted to convert a float to an integer we can pass our value to the `int` function. The conversion from integer to a float can be achieved in a similar manner by passing our value to the float function.

# %%
convert_to_int = int(1.6666667) # Note: Be Careful as it will conduct Floor Rounding
print(convert_to_int)

convert_to_float = float(4)
print(convert_to_float)
# Out:
# 1
# 4.0

# %% [markdown]
# ## **In-Class Code-Along: Expressions (20 Mins)**
#
# For this activity, the instructor will code live while you code along with them. As we go, we'll discuss different approaches to each question, ensuring everyone understands the process.
#
# Now that we have learned how to create variables in Python and work with expressions, let's work through an example together in class.
#
# ### Instructions
# 1. In the new cell below, write the following statements:
#     - x is equal to the number 25
#     - y is equal to the number 2
#     - z is equal to the number 999
# 2. Write 5 different expressions using x,y and z that evaluate to the number zero(0)
# 3. For only the 5th expression, assign that expression to a variable using an assignment statement
#     - Ex. five = (z / y / x) - 7 * y

# %%
# Write code here
x = 25
y = 2
z = 999
print(x, y, z)

#1st expr

expression_1 = z - 999
print(expression_1)

#2nd expr

expression_2 = (y - 1) + z - 1000
print(expression_2)

#3rd exp

expression_3 = (x - y) / 23 * 0
print(expression_3)

#4th exp

expression_4 = (z+1)-(x**y)-375
print(expression_4)

#5th exp

expression_5 = int((z+1)/y)-(x*20)
print(expression_5)
# Out:
# 25 2 999
# 0
# 0
# 0.0
# 0
# 0

# %% [markdown]
# ## Working with Strings

# %% [markdown]
# Note that a `string` in Python can be surrounded by single quotation marks or double quotation marks.
#
# Python allows us to perform mathematical operations on strings which will result in the creation of a new `string`. Using the first and last name from the example below, we can add or "concatenate" them together to create a person's full name.

# %%
# Examples of a string
f_name = "Payton"
l_name = "Yale"
favorite_book = 'Learning Python Essentials'

# %%
full_name = f_name + " " + l_name
print(full_name)
# Out:
# Payton Yale

# %% [markdown]
# What do you expect will happen in the code example below?

# %%
adding_number_types = 2 + 2
adding_string_types = '2' + '2'

print(adding_number_types)
print(adding_string_types)
# Out:
# 4
# 22

# %% [markdown]
# >Note: Operators function differently depending on type. For example: the `+` operator will **add** `number`s but **concatenate** `string`s.
#
# Furthermore, we can use the `*` operator to multiple strings together.

# %%
print('2' * 3)
print('#' * 10)
# Out:
# 222
# ##########

# %% [markdown]
# What do you think will happen when we try to multiple two strings together?

# %%
print('2' * '3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 print('2' * '3')
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# ## Working with Booleans
# Booleans represent a dichotomy as either a `True` or `False` value. We can use booleans to represent real-world dichotomies such as:
#  - Yes or No
#  - Correct or Incorrect
#  - Left or Right
#  - On or Off
#
# A combination of dichotomy expressions can create more complex comparisons. To combine `boolean` values we can use the "Boolean Operators" `and`, `or` and `not`

# %%
is_tall = True
is_short = not True
print(is_short)

im_tall = False
im_human = True

im_both = im_human and im_tall
print(im_both)

im_either = im_human or im_tall
print(im_either)
# Out:
# False
# False
# True

# %% [markdown]
# ## Control Flow
# Control flow allows us to make decisions in our code based on the result of a specific evaluation. These evaluations boil down to a `True` or `False` value and based on that value we can execute a specific piece of code.
#
# It is the combination of comparison, logical and boolean operators that helps us build complex expressions. We can write our code in such a way that once an expression evaluates to `True`, a particular section of our program will run.

# %%
# Basic conditionals
5 > 3 # True
0 > (3 + 5) * 2 # False
'hi' == 'hello' # False
# Out:
# False

# %% [markdown]
# ### Comparison Operators
#
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ### Logical Operators
#
# <img src="data:image/png;base64,..." />

# %% [markdown]
# Logical operators are used to chain expressions together allowing us to create more complex operations. The expressions on either side of a logical operator is known as an operand. Each operand is evaluated to Boolean context which will result in a `True` or `False` value. The result of the overall statement is dependent on the logical operator being used. Refer to the examples in the Logical Operators chart above to determine how each operator can produce a result of `True`.
#
# Determine what the result will be for the following:

# %%
x = False
y = True

print(x and y)
print(x or y)
print(not y)
# Out:
# False
# True
# False

# %% [markdown]
# It is important to know that all non-boolean operands are evaluated based on its boolean context to determine if its "truthy" or "falsy". There are several non-boolean values that will result in a False evaluation. These values include:
# - Any numerical operation that results in zero
# - An empty string
# - An empty list or dictionary
# - Python's `None` keyword

# %% [markdown]
# ### If and Else Statements
#
# Based on the outcome of a conditional, we can have our code "make decisions" or execute a specific block of code with the use of an if / else statement.

# %%
x = 5

if x>10:
    print("X seems to have value which is bigger than 10")
else:
    print("X seems to have lesser value than 10")
# Out:
# X seems to have lesser value than 10

# %%
x = 5
if (x > 3):
    print('running True block of code')
else:
    print('running False block of code')
# Out:
# running True block of code

# %% [markdown]
# Try altering the value of `x` to have the `else` block of code run.
#
# If we want to test multiple conditions, we can make use of the `elif` statement coupled with a normal if / else statement. It is important to know that the `else` statement is used to execute code when none of our conditions match our `if` or `elif` statements.

# %%
grade = 85

if (grade >= 90):
    print("Above Average")
elif (grade < 90 and grade >= 70):
    print("Average")
else:
    print("Below")
# Out:
# Average

# %% [markdown]
# Try altering the `grade` value to produce a result in each portion of our if statement.

# %% [markdown]
# ## **In-Class Code-Along: Control Flows (20 Mins)**
#
# For this activity, the instructor will code live while you code along with them. As we go, we'll discuss different approaches to each question, ensuring everyone understands the process.
#
# Now that we have learned how to create control flows in Python and work with If/Else statements, let's work through an example together in class.
#
# ### Instructions
#
# 1. Create a variable called “guess” and give it a value of seven. Write an if / elif/ else statement comparing the guess variable to the “random_num” variable.
#
#     - If the guess is lower than the random number, print “Guess is too low”
#     - If the guess is higher than the random number, print “Guess is too high”
#     - If neither condition matches, print “Your Guess is correct!”

# %%
 from random import randint
random_num = randint(0, 10)

# %%
# Write code here

# %% [markdown]
# # Key Takeaways
#
#
# - Variables in Python can be used to store various data types including strings, numbers or even booleans.
# - Various data types exist in Python including `strings`, `numbers` and `booleans`, which allow to deal with different types of data and perform various numerical or logical operations on them.
# - Control flows and mathematical operations can be used to create a decision-making process that acts based on the outcome of a condition.

# %% [markdown]
# # Next Up
# #### Lesson 2
#
# In real-world projects, data comes in various formats and types, necessitating organized storage for easier access and processing. In the next lesson, we'll introduce lists and dictionaries to efficiently manage these complex data collections. Additionally, we'll explore loops and functions, which allow for iterative inspection of data and automation of tasks. This approach enhances our ability to handle repetitive operations and streamlines coding processes for practical applications.

# %% [markdown]
# # Take-Home Exercise
#
# These exercises are provided for you to complete at home, helping you to reinforce and apply the concepts discussed in class. Attempt to solve them independently and bring any questions or points of discussion to our next session.
#
# For these exercises, you may have to look online to find some methods.

# %% [markdown]
# ### Instructions
# You’ve just finished eating at a restaurant and treated a friend to lunch. Calculate the total that you must pay given the following information. What was the cost of the tip alone?
#
# - Salad: \$3.99
# - Burger: \$12.99
# - Wings: \$13.99
# - Fries: \$3.50
#
# - Tax: 10%
# - Tip: 15% (In this situation, the tip must be applied to the after-tax cost of the food)

# %%
# Write your answer here.
s = 3.99
b = 12.99
w = 13.99
f = 3.5
tax = 0.10

expression_bt = (s + b + w + f) * (1+tax)
print(expression_bt)
# Out:
# 37.917

# %%
expression_tip = (expression_bt) * .15
print(expression_tip)
# Out:
# 5.68755

# %%
expression_total = (expression_bt) + (expression_tip)
print(expression_total)
# Out:
# 43.60455

# %% [markdown]
# You’ve been given a secret message from your friend, but all of the words are separated, concatenate the strings to piece together the message.

# %%
item = 'Pie'
action = 'buy the'
name = 'Armando'
verb = 'says'

# %%
# Write your answer here.
secret_message = name + " " + verb + " " + action + " " + item
print(secret_message)
print(f"{item} {action} {name} {verb}")
# Out:
# Armando says buy the Pie
# Pie buy the Armando says

# %% [markdown]
# You agree with Armando and decide to take some home for your family. You can share 10 amongst 4 people. How much should each family member receive? If we can only provide full ones, how much would be left over?

# %%
# Write your answer here.
# 10 pies shared amongst 4 people
pie_count = 10
people_count = 4

pies = pie_count / people_count
print(pies)

leftover_pie_count = pie_count % people_count
print(leftover_pie_count)
# Out:
# 2.5
# 2

# %% [markdown]
# <div id="container" style="position:relative;">
#     <div style="position:relative; float:right"><img style="height:25px""width: 50px" src="data:image/png;base64,..." />
#     </div>
# </div>
